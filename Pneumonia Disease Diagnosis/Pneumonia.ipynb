# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.models import Model,Sequential, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D,Input
from keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications import DenseNet121

# %%
disease_types=['PNEUMONIA', 'NORMAL']
data_dir = 'chest_xray'
train_dir = os.path.join(data_dir)

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
        
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])
train.head()
# Out:
#                                       File  DiseaseID Disease Type
# 0  PNEUMONIA/person1000_bacteria_2931.jpeg          0    PNEUMONIA
# 1     PNEUMONIA/person1000_virus_1681.jpeg          0    PNEUMONIA
# 2  PNEUMONIA/person1001_bacteria_2932.jpeg          0    PNEUMONIA
# 3  PNEUMONIA/person1002_bacteria_2933.jpeg          0    PNEUMONIA
# 4  PNEUMONIA/person1003_bacteria_2934.jpeg          0    PNEUMONIA

# %%
SEED = 42
train = train.sample(frac=1, random_state=SEED) 
train.index = np.arange(len(train))
train.head()
# Out:
#                                       File  DiseaseID Disease Type
# 0   PNEUMONIA/person299_bacteria_1418.jpeg          0    PNEUMONIA
# 1     PNEUMONIA/person1415_virus_2425.jpeg          0    PNEUMONIA
# 2    NORMAL/NORMAL2-IM-0416-0001-0002.jpeg          1       NORMAL
# 3         NORMAL/NORMAL2-IM-0757-0001.jpeg          1       NORMAL
# 4  PNEUMONIA/person1924_bacteria_4833.jpeg          0    PNEUMONIA

# %%
plt.hist(train['DiseaseID'])
plt.title('Frequency Histogram of Species')
plt.figure(figsize=(12, 12))
plt.show()

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
# Displays first n images of class from training set
plot_defects('PNEUMONIA', 5, 5)

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
plot_defects('NORMAL', 5, 5)

# %%
IMAGE_SIZE = 64
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath))
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 5216it [01:21, 63.95it/s]
# Train Shape: (5216, 64, 64, 3)

# %%
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=2)

# %%
BATCH_SIZE = 64

# Split the train and validation sets 
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.2, random_state=SEED)

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 15))
for i in range(3):
    ax[i].set_axis_off()
    ax[i].imshow(X_train[i])
    ax[i].set_title(disease_types[np.argmax(Y_train[i])])

# %%
EPOCHS = 50
SIZE=64
N_ch=3

# %%
from keras.optimizers import Adam

# %%
def build_densenet():
    densenet = DenseNet121(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = densenet(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(2,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    
    optimizer = Adam(learning_rate=0.002, beta_1=0.9, beta_2=0.999, epsilon=0.1)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    return model

# %%
# Implement early stopping
from keras.callbacks import EarlyStopping

# %%
model = build_densenet()
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('pneumonia.h5', verbose=1, save_best_only=True)

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Generates batches of image data with data augmentation
datagen = ImageDataGenerator(rotation_range=360,
                        width_shift_range=0.2,
                        height_shift_range=0.2,
                        zoom_range=0.2,
                        horizontal_flip=True,
                        vertical_flip=True)

datagen.fit(X_train)
# Fits the model on batches with real-time data augmentation
hist = model.fit(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint,early_stopping],
               validation_data=(X_val, Y_val))
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  conv2d (Conv2D)             (None, 64, 64, 3)         84
#
#  densenet121 (Functional)    (None, None, None, 1024   7037504
#                              )
#
#  global_average_pooling2d (  (None, 1024)              0
#  GlobalAveragePooling2D)
#
#  batch_normalization (Batch  (None, 1024)              4096
#  Normalization)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 256)               262400
#
#  batch_normalization_1 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  root (Dense)                (None, 2)                 514
#
# =================================================================
# Total params: 7305622 (27.87 MB)
# Trainable params: 7219414 (27.54 MB)
# Non-trainable params: 86208 (336.75 KB)
# _________________________________________________________________
# Epoch 1/50
#
# Epoch 1: val_loss improved from inf to 0.77855, saving model to pneumonia.h5
# C:\Users\addur\anaconda3\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 65/65 - 171s - loss: 1.0056 - accuracy: 0.6193 - val_loss: 0.7786 - val_accuracy: 0.5326 - lr: 0.0020 - 171s/epoch - 3s/step
# Epoch 2/50
#
# Epoch 2: val_loss improved from 0.77855 to 0.51875, saving model to pneumonia.h5
# 65/65 - 139s - loss: 0.6474 - accuracy: 0.7646 - val_loss: 0.5188 - val_accuracy: 0.7586 - lr: 0.0020 - 139s/epoch - 2s/step
# Epoch 3/50
#
# Epoch 3: val_loss improved from 0.51875 to 0.31849, saving model to pneumonia.h5
# 65/65 - 141s - loss: 0.4637 - accuracy: 0.8471 - val_loss: 0.3185 - val_accuracy: 0.8707 - lr: 0.0020 - 141s/epoch - 2s/step
# Epoch 4/50
#
# Epoch 4: val_loss improved from 0.31849 to 0.27387, saving model to pneumonia.h5
# 65/65 - 143s - loss: 0.3782 - accuracy: 0.8720 - val_loss: 0.2739 - val_accuracy: 0.9128 - lr: 0.0020 - 143s/epoch - 2s/step
# Epoch 5/50
#
# Epoch 5: val_loss did not improve from 0.27387
# 65/65 - 140s - loss: 0.3059 - accuracy: 0.8951 - val_loss: 0.3043 - val_accuracy: 0.8506 - lr: 0.0020 - 140s/epoch - 2s/step
# Epoch 6/50
#
# Epoch 6: val_loss did not improve from 0.27387
# 65/65 - 141s - loss: 0.2695 - accuracy: 0.9075 - val_loss: 0.3882 - val_accuracy: 0.9435 - lr: 0.0020 - 141s/epoch - 2s/step
# Epoch 7/50
#
# Epoch 7: val_loss did not improve from 0.27387
# 65/65 - 140s - loss: 0.2238 - accuracy: 0.9214 - val_loss: 0.7054 - val_accuracy: 0.9042 - lr: 0.0020 - 140s/epoch - 2s/step
# Epoch 8/50
#
# Epoch 8: val_loss did not improve from 0.27387
# 65/65 - 140s - loss: 0.2519 - accuracy: 0.9146 - val_loss: 1.1139 - val_accuracy: 0.8841 - lr: 0.0020 - 140s/epoch - 2s/step
# Epoch 9/50
#
# Epoch 9: val_loss improved from 0.27387 to 0.20550, saving model to pneumonia.h5
# 65/65 - 142s - loss: 0.1912 - accuracy: 0.9316 - val_loss: 0.2055 - val_accuracy: 0.9454 - lr: 0.0020 - 142s/epoch - 2s/step
# Epoch 10/50
#
# Epoch 10: val_loss did not improve from 0.20550
# 65/65 - 141s - loss: 0.2004 - accuracy: 0.9316 - val_loss: 1.8466 - val_accuracy: 0.8458 - lr: 0.0020 - 141s/epoch - 2s/step
# Epoch 11/50
#
# Epoch 11: val_loss did not improve from 0.20550
# 65/65 - 140s - loss: 0.1901 - accuracy: 0.9350 - val_loss: 0.2147 - val_accuracy: 0.9119 - lr: 0.0020 - 140s/epoch - 2s/step
# Epoch 12/50
#
# Epoch 12: val_loss did not improve from 0.20550
# 65/65 - 141s - loss: 0.1647 - accuracy: 0.9404 - val_loss: 0.2828 - val_accuracy: 0.9377 - lr: 0.0020 - 141s/epoch - 2s/step
# Epoch 13/50
#
# Epoch 13: val_loss did not improve from 0.20550
# 65/65 - 142s - loss: 0.1666 - accuracy: 0.9433 - val_loss: 0.5735 - val_accuracy: 0.8803 - lr: 0.0020 - 142s/epoch - 2s/step
# Epoch 14/50
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 14: val_loss did not improve from 0.20550
# 65/65 - 146s - loss: 0.1578 - accuracy: 0.9484 - val_loss: 0.2684 - val_accuracy: 0.9339 - lr: 0.0020 - 146s/epoch - 2s/step
# Epoch 15/50
#
# Epoch 15: val_loss improved from 0.20550 to 0.12885, saving model to pneumonia.h5
# 65/65 - 142s - loss: 0.1648 - accuracy: 0.9438 - val_loss: 0.1289 - val_accuracy: 0.9540 - lr: 0.0010 - 142s/epoch - 2s/step
# Epoch 16/50
#
# Epoch 16: val_loss improved from 0.12885 to 0.11891, saving model to pneumonia.h5
# 65/65 - 144s - loss: 0.1437 - accuracy: 0.9495 - val_loss: 0.1189 - val_accuracy: 0.9617 - lr: 0.0010 - 144s/epoch - 2s/step
# Epoch 17/50
#
# Epoch 17: val_loss did not improve from 0.11891
# 65/65 - 142s - loss: 0.1277 - accuracy: 0.9540 - val_loss: 0.2460 - val_accuracy: 0.9387 - lr: 0.0010 - 142s/epoch - 2s/step
# Epoch 18/50
#
# Epoch 18: val_loss did not improve from 0.11891
# 65/65 - 142s - loss: 0.1760 - accuracy: 0.9416 - val_loss: 0.4873 - val_accuracy: 0.7960 - lr: 0.0010 - 142s/epoch - 2s/step
# Epoch 19/50
#
# Epoch 19: val_loss improved from 0.11891 to 0.11676, saving model to pneumonia.h5
# 65/65 - 142s - loss: 0.1342 - accuracy: 0.9576 - val_loss: 0.1168 - val_accuracy: 0.9626 - lr: 0.0010 - 142s/epoch - 2s/step
# Epoch 20/50
#
# Epoch 20: val_loss did not improve from 0.11676
# 65/65 - 141s - loss: 0.1357 - accuracy: 0.9525 - val_loss: 0.1773 - val_accuracy: 0.9291 - lr: 0.0010 - 141s/epoch - 2s/step
# Epoch 21/50
#
# Epoch 21: val_loss did not improve from 0.11676
# 65/65 - 140s - loss: 0.1187 - accuracy: 0.9537 - val_loss: 0.1714 - val_accuracy: 0.9492 - lr: 0.0010 - 140s/epoch - 2s/step
# Epoch 22/50
#
# Epoch 22: val_loss did not improve from 0.11676
# 65/65 - 139s - loss: 0.1362 - accuracy: 0.9562 - val_loss: 0.1407 - val_accuracy: 0.9511 - lr: 0.0010 - 139s/epoch - 2s/step
# Epoch 23/50
#
# Epoch 23: val_loss did not improve from 0.11676
# 65/65 - 140s - loss: 0.1246 - accuracy: 0.9572 - val_loss: 0.1601 - val_accuracy: 0.9492 - lr: 0.0010 - 140s/epoch - 2s/step
# Epoch 24/50
#
# Epoch 24: val_loss did not improve from 0.11676
# 65/65 - 140s - loss: 0.1305 - accuracy: 0.9540 - val_loss: 0.1200 - val_accuracy: 0.9569 - lr: 0.0010 - 140s/epoch - 2s/step
# Epoch 25/50
#
# Epoch 25: val_loss did not improve from 0.11676
# 65/65 - 140s - loss: 0.1150 - accuracy: 0.9596 - val_loss: 0.7728 - val_accuracy: 0.8027 - lr: 0.0010 - 140s/epoch - 2s/step
# Epoch 26/50
#
# Epoch 26: val_loss did not improve from 0.11676
# 65/65 - 140s - loss: 0.1123 - accuracy: 0.9564 - val_loss: 0.1837 - val_accuracy: 0.9473 - lr: 0.0010 - 140s/epoch - 2s/step
# Epoch 27/50
#
# Epoch 27: val_loss did not improve from 0.11676
# 65/65 - 140s - loss: 0.1087 - accuracy: 0.9589 - val_loss: 0.1250 - val_accuracy: 0.9579 - lr: 0.0010 - 140s/epoch - 2s/step
# Epoch 28/50
#
# Epoch 28: val_loss did not improve from 0.11676
# 65/65 - 140s - loss: 0.1123 - accuracy: 0.9579 - val_loss: 0.1457 - val_accuracy: 0.9540 - lr: 0.0010 - 140s/epoch - 2s/step
# Epoch 29/50
#
# Epoch 29: val_loss did not improve from 0.11676
# 65/65 - 141s - loss: 0.1025 - accuracy: 0.9613 - val_loss: 0.1291 - val_accuracy: 0.9569 - lr: 0.0010 - 141s/epoch - 2s/step

# %%
final_loss, final_accuracy = model.evaluate(X_val, Y_val)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# 33/33 [==============================] - 8s 245ms/step - loss: 0.1168 - accuracy: 0.9626
# Final Loss: 0.11675817519426346, Final Accuracy: 0.9626436829566956

# %%
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# 33/33 [==============================] - 10s 237ms/step
# Text(0.5, 192.72222222222217, 'Predicted')

# %%
# accuracy plot 
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# loss plot
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from skimage import io
from keras.preprocessing import image
img = image.load_img('chest_xray/NORMAL/IM-0195-0001.jpeg', grayscale=False, target_size=(64, 64))
show_img=image.load_img('chest_xray/NORMAL/IM-0195-0001.jpeg', grayscale=False, target_size=(200, 200))
disease_class=['PNEUMONIA','NORMAL']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x /= 255

custom = model.predict(x)
print(custom[0])

plt.imshow(show_img)
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# 1/1 [==============================] - 0s 34ms/step
# [2.9132187e-05 9.9997091e-01]
# Prediction: NORMAL
